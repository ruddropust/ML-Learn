# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r'C:\Users\shark\Desktop\ML Learn\WSCubeTech Part 2\Dataset\Salary_Data.csv')
dataset.head()
# Out:
#     Age  YearsofExperience    Salary
# 0  32.0                5.0   90000.0
# 1  28.0                3.0   65000.0
# 2  45.0               15.0  150000.0
# 3  36.0                7.0   60000.0
# 4  52.0               20.0  200000.0

# %%
sns.scatterplot(x='Age', y='YearsofExperience', data=dataset, hue='Salary')
# Out:
# <Axes: xlabel='Age', ylabel='YearsofExperience'>

# %%
dataset.isnull().sum()
# Out:
# Age                  2
# YearsofExperience    3
# Salary               5
# dtype: int64

# %%
dataset.dropna(inplace=True)
dataset.isnull().sum()
# Out:
# Age                  0
# YearsofExperience    0
# Salary               0
# dtype: int64

# %%
x = dataset.iloc[:,:-1]
y = dataset["Salary"]
print(x)
print(y)
# Out:
#        Age  YearsofExperience
# 0     32.0                5.0
# 1     28.0                3.0
# 2     45.0               15.0
# 3     36.0                7.0
# 4     52.0               20.0
# ...    ...                ...
# 6699  49.0               20.0
# 6700  32.0                3.0
# 6701  30.0                4.0
# 6702  46.0               14.0
# 6703  26.0                1.0
#
# [6699 rows x 2 columns]
# 0        90000.0
# 1        65000.0
# 2       150000.0
# 3        60000.0
# 4       200000.0
#           ...
# 6699    200000.0
# 6700     50000.0
# 6701     55000.0
# 6702    140000.0
# 6703     35000.0
# Name: Salary, Length: 6699, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state=42)

# %%
from sklearn.neighbors import KNeighborsRegressor
knr = KNeighborsRegressor(n_neighbors=3)
knr.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
knr.score(x_test,y_test)*100
# Out:
# 78.27601674883404

# %%
for i in range(1,20):
    knr1 = KNeighborsRegressor(n_neighbors=i)
    knr1.fit(x_train,y_train)
    print('For', i, 'Test Accuracy is:', knr1.score(x_test, y_test)*100)
    print('For', i, 'Train Accuracy is:', knr1.score(x_train, y_train)*100)
    print("--------------------------------------------------")
# Out:
# For 1 Test Accuracy is: 69.94125535129237
# For 1 Train Accuracy is: 69.24816693155084
# --------------------------------------------------
# For 2 Test Accuracy is: 77.18536575151997
# For 2 Train Accuracy is: 78.74862265421596
# --------------------------------------------------
# For 3 Test Accuracy is: 78.27601674883404
# For 3 Train Accuracy is: 80.23229143466561
# --------------------------------------------------
# For 4 Test Accuracy is: 79.475760811114
# For 4 Train Accuracy is: 80.80766088870463
# --------------------------------------------------
# For 5 Test Accuracy is: 80.87681780043572
# For 5 Train Accuracy is: 82.26930986091261
# --------------------------------------------------
# For 6 Test Accuracy is: 81.80187782206174
# For 6 Train Accuracy is: 83.0085228292476
# --------------------------------------------------
# For 7 Test Accuracy is: 82.08685893724443
# For 7 Train Accuracy is: 83.48223492540721
# --------------------------------------------------
# ...
